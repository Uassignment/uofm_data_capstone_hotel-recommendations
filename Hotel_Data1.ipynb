# %%
import pandas as pd
import numpy as np

# %%
url= "https://ralston-hotel-data-bucket.s3.amazonaws.com/Hotel_Reviews.csv"

# %%
df = pd.read_csv(url)

# %%
df.head()
# Out:
#                                        Hotel_Address  \
# 0   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 1   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 2   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 3   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 4   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
#
#    Additional_Number_of_Scoring Review_Date  Average_Score   Hotel_Name  \
# 0                           194    8/3/2017            7.7  Hotel Arena
# 1                           194    8/3/2017            7.7  Hotel Arena
# 2                           194   7/31/2017            7.7  Hotel Arena
# 3                           194   7/31/2017            7.7  Hotel Arena
# 4                           194   7/24/2017            7.7  Hotel Arena
#
#   Reviewer_Nationality                                    Negative_Review  \
# 0              Russia    I am so angry that i made this post available...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 515738 entries, 0 to 515737
# Data columns (total 17 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   Hotel_Address                               515738 non-null  object
#  1   Additional_Number_of_Scoring                515738 non-null  int64
#  2   Review_Date                                 515738 non-null  object
#  3   Average_Score                               515738 non-null  float64
#  4   Hotel_Name                                  515738 non-null  object
#  5   Reviewer_Nationality                        515738 non-null  object
#  6   Negative_Review                             515738 non-null  object
#  7   Review_Total_Negative_Word_Counts           515738 non-null  int64
#  8   Total_Number_of_Reviews                     515738 non-null  int64
# ...

# %%
df.describe()
# Out:
#        Additional_Number_of_Scoring  Average_Score  \
# count                 515738.000000  515738.000000
# mean                     498.081836       8.397487
# std                      500.538467       0.548048
# min                        1.000000       5.200000
# 25%                      169.000000       8.100000
# 50%                      341.000000       8.400000
# 75%                      660.000000       8.800000
# max                     2682.000000       9.800000
#
#        Review_Total_Negative_Word_Counts  Total_Number_of_Reviews  \
# count                      515738.000000            515738.000000
# mean                           18.539450              2743.743944
# std                            29.690831              2317.464868
# min                             0.000000                43.000000
# 25%                             2.000000              1161.000000
# 50%                             9.000000              2134.000000
# ...

# %%
df["Review_Date"]=pd.to_datetime(df.Review_Date)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 515738 entries, 0 to 515737
# Data columns (total 17 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   Hotel_Address                               515738 non-null  object
#  1   Additional_Number_of_Scoring                515738 non-null  int64
#  2   Review_Date                                 515738 non-null  datetime64[ns]
#  3   Average_Score                               515738 non-null  float64
#  4   Hotel_Name                                  515738 non-null  object
#  5   Reviewer_Nationality                        515738 non-null  object
#  6   Negative_Review                             515738 non-null  object
#  7   Review_Total_Negative_Word_Counts           515738 non-null  int64
#  8   Total_Number_of_Reviews                     515738 non-null  int64
# ...

# %%
#drop null lat/long, bin tags?, no negative or positive replace with null values?  
#binary column 0-4 neg, 5-10 positive, natural language code nltk, create random sample
#goodreads example

# %%
tags = set()

for x in df.Tags:
    for tag in x.split(","):
        tag = tag.strip("[").strip("]").strip("'").strip().strip("'").strip()
        tags.add(tag)

# %%
tags
# Out:
# {'Deluxe Double or Twin Room with Panoramic Sea View',
#  'Deluxe Room 2 Adults',
#  'Superior Executive Room with Executive Lounge Access',
#  'Single Room Annex',
#  'Deluxe Junior Suite with Spa Bath',
#  'Deluxe Room with Spa Fitness Access',
#  'Stanhope Suite',
#  'Deluxe Junior Suite',
#  'Luxury Triple Room with Garden View',
#  'Delightful King Twin Room',
#  'Luxury Suite with Garden View',
#  'King Hilton Guestroom',
#  'Junior Suite Double',
#  'Executive King Room',
#  'Twin or Double Room with Terrace',
#  'Pasha Suite',
#  'Junior Suite with Hydromassage Shower',
#  'Grand Deluxe King or Twin Room',
#  'Budget Double Room',
#  '2 rooms',
#  'Double or Twin Room with Garden View',
#  'Duke of Monmouth Suite',
#  'Senior Suite 1 3 Adults',
#  'Premier Twin Room',
#  'Classic Designer',
#  'Premium Double Room with Views',
#  'Special Offer Single Room with Continental Breakfast',
#  'Executive King or Twin Room with Lounge Access',
# ...

# %%
len(tags)
# Out:
# 2428

# %%
#too many unique tags
