# %%
import pandas as pd
import numpy as np

# %%
url= "https://ralston-hotel-data-bucket.s3.amazonaws.com/Hotel_Reviews_Clean.csv"

# %%
hotel_df = pd.read_csv(url)

# %%
hotel_df.head()
# Out:
#    Unnamed: 0                                      Hotel_Address  \
# 0           0   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 1           1   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 2           2   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 3           3   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 4           4   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
#
#    Additional_Number_of_Scoring Review_Date  Average_Score   Hotel_Name  \
# 0                           194  2017-08-03            7.7  Hotel Arena
# 1                           194  2017-08-03            7.7  Hotel Arena
# 2                           194  2017-07-31            7.7  Hotel Arena
# 3                           194  2017-07-31            7.7  Hotel Arena
# 4                           194  2017-07-24            7.7  Hotel Arena
#
#   Reviewer_Nationality                                    Negative_Review  \
# 0              Russia    I am so angry that i made this post available...
# 1             Ireland                                         No Negative
# 2           Australia    Rooms are nice but for elderly a bit difficul...
# 3      United Kingdom    My room was dirty and I was afraid to walk ba...
# 4         New Zealand    You When I booked with your company on line y...
#
#    Review_Total_Negative_Word_Counts  Total_Number_of_Reviews  \
# 0                                397                     1403
# 1                                  0                     1403
# 2                                 42                     1403
# 3                                210                     1403
# 4                                140                     1403
#
#                                      Positive_Review  \
# 0   Only the park outside of the hotel was beauti...
# 1   No real complaints the hotel was great great ...
# 2   Location was good and staff were ok It is cut...
# 3   Great location in nice surroundings the bar a...
# 4    Amazing location and building Romantic setting
#
#    Review_Total_Positive_Word_Counts  \
# 0                                 11
# 1                                105
# 2                                 21
# 3                                 26
# 4                                  8
#
#    Total_Number_of_Reviews_Reviewer_Has_Given  Reviewer_Score  \
# 0                                           7             2.9
# 1                                           7             7.5
# 2                                           9             7.1
# 3                                           1             3.8
# 4                                           3             6.7
#
#                                                 Tags days_since_review  \
# 0  [' Leisure trip ', ' Couple ', ' Duplex Double...            0 days
# 1  [' Leisure trip ', ' Couple ', ' Duplex Double...            0 days
# 2  [' Leisure trip ', ' Family with young childre...            3 days
# 3  [' Leisure trip ', ' Solo traveler ', ' Duplex...            3 days
# 4  [' Leisure trip ', ' Couple ', ' Suite ', ' St...           10 days
#
#          lat       lng Hotel_Country Sentiment
# 0  52.360576  4.915968   Netherlands  Negative
# 1  52.360576  4.915968   Netherlands  Positive
# 2  52.360576  4.915968   Netherlands  Positive
# 3  52.360576  4.915968   Netherlands  Negative
# 4  52.360576  4.915968   Netherlands  Positive

# %%
#create random sample of original dataset - 5% sample
hotel_sample_df = hotel_df.sample(frac=.05)

# %%
hotel_sample_df.head()
# Out:
#         Unnamed: 0                                      Hotel_Address  \
# 407200      408924  Piazza Luigi di Savoia 20 Central Station 2012...
# 212198      212580  54 Upper Berkeley Street Westminster Borough L...
# 38507        38507  12 Lancaster Gate Lancaster Gate Westminster B...
# 420894      422618  Prinses Irenestraat 30 Zuideramstel 1077 WX Am...
# 346977      347659  IJdock 6 Amsterdam City Center 1013 MM Amsterd...
#
#         Additional_Number_of_Scoring Review_Date  Average_Score  \
# 407200                           264  2017-06-05            8.7
# 212198                           130  2015-10-23            8.5
# 38507                            440  2017-07-08            8.0
# 420894                           726  2015-12-15            8.6
# 346977                           550  2017-04-08            8.8
#
#                                      Hotel_Name        Reviewer_Nationality  \
# 407200                      Starhotels Anderson   United States of America
# 212198                         The Sumner Hotel             United Kingdom
# 38507   Best Western Mornington Hotel Hyde Park   United States of America
# 420894                       citizenM Amsterdam                Netherlands
# 346977                         Room Mate Aitana             United Kingdom
#
#                                           Negative_Review  \
# 407200   The fan unit rattled all night long Next morn...
# 212198                                        No Negative
# 38507    Small rooms with natrow corridors There was a...
# 420894                                 No window to open
# 346977   Lots of noise from outside early in the morning
#
#         Review_Total_Negative_Word_Counts  Total_Number_of_Reviews  \
# 407200                                 49                     2698
# 212198                                  0                      762
# 38507                                  29                     2418
# 420894                                  6                     4530
# 346977                                 11                     4097
#
#                                           Positive_Review  \
# 407200                   Relatively modern updated hotel
# 212198   Very stylish hotel High quality furnishings a...
# 38507    Small comfortable hotel within walking distan...
# 420894   Room was small but with all the necessary fac...
# 346977   Bar was good value for money and the staff we...
#
#         Review_Total_Positive_Word_Counts  \
# 407200                                  6
# 212198                                 31
# 38507                                  20
# 420894                                 24
# 346977                                 14
#
#         Total_Number_of_Reviews_Reviewer_Has_Given  Reviewer_Score  \
# 407200                                           3             5.0
# 212198                                           4             9.6
# 38507                                           15             7.5
# 420894                                           6             7.9
# 346977                                           9             9.6
#
#                                                      Tags days_since_review  \
# 407200  [' Leisure trip ', ' Family with young childre...           59 days
# 212198  [' Leisure trip ', ' Family with older childre...           650 day
# 38507   [' Leisure trip ', ' Couple ', ' Economy Doubl...           26 days
# 420894  [' Leisure trip ', ' Couple ', ' Double Room '...           597 day
# 346977  [' Leisure trip ', ' Couple ', ' Queen or Two ...           117 day
#
#               lat       lng Hotel_Country Sentiment
# 407200  45.485255  9.206950         Italy  Negative
# 212198  51.515289 -0.160898            UK  Positive
# 38507   51.511993 -0.178279            UK  Positive
# 420894  52.341943  4.875960   Netherlands  Positive
# 346977  52.384606  4.894187   Netherlands  Positive

# %%
from ast import literal_eval

# %%
def impute(column):
    column = column[0]
    if (type(column) != list):
        return "".join(literal_eval(column))
    else:
        return column
    
hotel_sample_df["Tags"] = hotel_sample_df[["Tags"]].apply(impute, axis=1)
hotel_sample_df.head()
# Out:
#         Unnamed: 0                                      Hotel_Address  \
# 407200      408924  Piazza Luigi di Savoia 20 Central Station 2012...
# 212198      212580  54 Upper Berkeley Street Westminster Borough L...
# 38507        38507  12 Lancaster Gate Lancaster Gate Westminster B...
# 420894      422618  Prinses Irenestraat 30 Zuideramstel 1077 WX Am...
# 346977      347659  IJdock 6 Amsterdam City Center 1013 MM Amsterd...
#
#         Additional_Number_of_Scoring Review_Date  Average_Score  \
# 407200                           264  2017-06-05            8.7
# 212198                           130  2015-10-23            8.5
# 38507                            440  2017-07-08            8.0
# 420894                           726  2015-12-15            8.6
# 346977                           550  2017-04-08            8.8
#
#                                      Hotel_Name        Reviewer_Nationality  \
# 407200                      Starhotels Anderson   United States of America
# 212198                         The Sumner Hotel             United Kingdom
# 38507   Best Western Mornington Hotel Hyde Park   United States of America
# 420894                       citizenM Amsterdam                Netherlands
# 346977                         Room Mate Aitana             United Kingdom
#
#                                           Negative_Review  \
# 407200   The fan unit rattled all night long Next morn...
# 212198                                        No Negative
# 38507    Small rooms with natrow corridors There was a...
# 420894                                 No window to open
# 346977   Lots of noise from outside early in the morning
#
#         Review_Total_Negative_Word_Counts  Total_Number_of_Reviews  \
# 407200                                 49                     2698
# 212198                                  0                      762
# 38507                                  29                     2418
# 420894                                  6                     4530
# 346977                                 11                     4097
#
#                                           Positive_Review  \
# 407200                   Relatively modern updated hotel
# 212198   Very stylish hotel High quality furnishings a...
# 38507    Small comfortable hotel within walking distan...
# 420894   Room was small but with all the necessary fac...
# 346977   Bar was good value for money and the staff we...
#
#         Review_Total_Positive_Word_Counts  \
# 407200                                  6
# 212198                                 31
# 38507                                  20
# 420894                                 24
# 346977                                 14
#
#         Total_Number_of_Reviews_Reviewer_Has_Given  Reviewer_Score  \
# 407200                                           3             5.0
# 212198                                           4             9.6
# 38507                                           15             7.5
# 420894                                           6             7.9
# 346977                                           9             9.6
#
#                                                      Tags days_since_review  \
# 407200   Leisure trip  Family with young children  2 r...           59 days
# 212198   Leisure trip  Family with older children  Exe...           650 day
# 38507    Leisure trip  Couple  Economy Double Room  St...           26 days
# 420894   Leisure trip  Couple  Double Room  Stayed 1 n...           597 day
# 346977   Leisure trip  Couple  Queen or Two Double Bed...           117 day
#
#               lat       lng Hotel_Country Sentiment
# 407200  45.485255  9.206950         Italy  Negative
# 212198  51.515289 -0.160898            UK  Positive
# 38507   51.511993 -0.178279            UK  Positive
# 420894  52.341943  4.875960   Netherlands  Positive
# 346977  52.384606  4.894187   Netherlands  Positive

# %%
hotel_sample_df['Hotel_Country'] = hotel_sample_df['Hotel_Country'].str.lower()
hotel_sample_df['Tags'] = hotel_sample_df['Tags'].str.lower()

# %%
import nltk
nltk.download('wordnet')
import numpy as np
import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer
from ast import literal_eval
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\16513\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
def recommend_hotel(location, description):
    description = description.lower()
    word_tokenize(description)
    stop_words = stopwords.words('english')
    lemm = WordNetLemmatizer()
    filtered  = {word for word in description if not word in stop_words}
    filtered_set = set()
    for fs in filtered:
        filtered_set.add(lemm.lemmatize(fs))
        
    country = hotel_sample_df[hotel_sample_df["Hotel_Country"]==location.lower()]
    country = country.set_index(np.arange(country.shape[0]))
    list1 = []; list2 = []; cos = [];
    for i in range(country.shape[0]):
        temp_token = word_tokenize(country["Hotel_Country"][i])
        temp_set = [word for word in temp_token if not word in stop_words]
        temp2_set = set()
        for s in temp_set:
                temp2_set.add(lemm.lemmatize(s))
        vector = temp2_set.intersection(filtered_set)
        cos.append(len(vector))
    country['similarity']=cos
    country = country.sort_values(by='similarity', ascending=False)
    country.drop_duplicates(subset='Hotel_Name', keep='first', inplace=True)
    country.sort_values('Average_Score', ascending=False, inplace=True)
    country.reset_index(inplace=True)
    return country[["Hotel_Name", "Average_Score", "Hotel_Address"]].head()

# %%
recommend_hotel('UK', 'pool')
# Out:
#                    Hotel_Name  Average_Score  \
# 0             Haymarket Hotel            9.6
# 1                          41            9.6
# 2  Milestone Hotel Kensington            9.5
# 3      Charlotte Street Hotel            9.5
# 4              The Soho Hotel            9.5
#
#                                        Hotel_Address
# 0  1 Suffolk Place Westminster Borough London SW1...
# 1  41 Buckingham Palace Road Westminster Borough ...
# 2  1 Kensington Court Kensington and Chelsea Lond...
# 3  15 17 Charlotte Street Hotel Westminster Borou...
# 4  4 Richmond Mews Westminster Borough London W1D...

# %%
#country only
def hotel_country(location):
    stop_words = stopwords.words('english')
    lemm = WordNetLemmatizer()
    filtered  = {word for word in location if not word in stop_words}
    filtered_set = set()
    for fs in filtered:
        filtered_set.add(lemm.lemmatize(fs))
       
    country = hotel_sample_df[hotel_sample_df["Hotel_Country"]==location.lower()]
    country = country.set_index(np.arange(country.shape[0]))
    list1 = []; list2 = []; cos = [];
    for i in range(country.shape[0]):
        temp_token = word_tokenize(country["Hotel_Country"][i])
        temp_set = [word for word in temp_token if not word in stop_words]
        temp2_set = set()
        for s in temp_set:
                temp2_set.add(lemm.lemmatize(s))
        vector = temp2_set.intersection(filtered_set)
        cos.append(len(vector))
    country['similarity']=cos
    country = country.sort_values(by='similarity', ascending=False)
    country.drop_duplicates(subset='Hotel_Name', keep='first', inplace=True)
    country.sort_values('Average_Score', ascending=False, inplace=True)
    country.reset_index(inplace=True)
    return country[["Hotel_Name", "Average_Score", "Hotel_Address", "Positive_Review", "Negative_Review", "lat", "lng"]].head()

# %%
hotel_country('France')
# Out:
#                             Hotel_Name  Average_Score  \
# 0                           Ritz Paris            9.8
# 1  H tel de La Tamise Esprit de France            9.6
# 2            Hotel The Peninsula Paris            9.5
# 3                Le Narcisse Blanc Spa            9.5
# 4                     H tel D Aubusson            9.4
#
#                                        Hotel_Address  \
# 0        15 Place Vend me 1st arr 75001 Paris France
# 1           4 rue d Alger 1st arr 75001 Paris France
# 2       19 avenue Kleber 16th arr 75116 Paris France
# 3  19 Boulevard De La Tour Maubourg 7th arr 75007...
# 4         33 Rue Dauphine 6th arr 75006 Paris France
#
#                                      Positive_Review  \
# 0   Excellent hotel food and drinks exceptional R...
# 1                       Exceptional customer service
# 2          Top class hotel in any way But not cheap
# 3   Exceptional location in the middle of all the...
# 4   the warm welcome the friendlinesses of the st...
#
#                                      Negative_Review        lat       lng
# 0                              Rooms could be larger  48.867947  2.328959
# 1                                               None  48.864866  2.329576
# 2   We had some issues at the end but they were s...  48.871060  2.293354
# 3                                        No Negative  48.860512  2.310653
# 4                                        No Negative  48.854733  2.339528
